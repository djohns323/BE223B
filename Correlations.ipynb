# %%
import pandas as pd

# %%
jsons_processed = pd.read_csv('Downloads/jsons_processed.csv')

# %%
jsons_processed['text']
# Out:
# 0                                       mention hey beauti
# 1                                 mention good morn beauti
# 2        use shazam discov da art storytelin part outka...
# 3          use shazam discov joy teddi pendergra hyperlink
# 4         listen inch feat weknd beyoncé mention hyperlink
# 5                                   mention mention beauti
# 6                                   realli feel life right
# 7                                                     imag
# 8                                                     imag
# 9                                        mention good morn
# 10                                    mention omg gorgeous
# 11                              mention good morn gorgeous
# 12                                       mention good morn
# 13                                       mention good morn
# 14            use shazam discov famous kany west hyperlink
# 15                                                    imag
# ...

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Downloads/tweets_concatenated.csv')

# %%
idcol = 'user_id'
new_features = df
new_features.index = new_features[idcol]
labels = pd.read_csv('Desktop/tweet_files-1/tweet_files/twitter-data-deidentified.csv', index_col='record_id')

# %%
full_data = pd.merge(new_features, labels, how='inner', on=None, left_on=None, right_on=None, left_index=True, right_index=True).drop([idcol], axis=1)

# %%
full_data.corr()
# Out:
#                Unnamed: 0     likes  n_tweets   replies  retweets  \
# Unnamed: 0       1.000000  0.088575  0.034680  0.044881  0.088371
# likes            0.088575  1.000000  0.527547  0.887213  0.999783
# n_tweets         0.034680  0.527547  1.000000  0.715224  0.524616
# replies          0.044881  0.887213  0.715224  1.000000  0.889119
# retweets         0.088371  0.999783  0.524616  0.889119  1.000000
# time_business   -0.054300  0.038915 -0.039823  0.004050  0.039451
# time_early      -0.010905 -0.040486  0.008108 -0.051318 -0.038793
# time_evening     0.105963  0.026709  0.012208  0.033532  0.027442
# time_late       -0.008314 -0.030539  0.025928  0.005257 -0.032527
# weekday_mean     0.004916  0.031060  0.073999  0.046096  0.030977
# wkday_0          0.056255 -0.005514 -0.050823 -0.024182 -0.005294
# wkday_1          0.018739 -0.017369 -0.005394 -0.013415 -0.017714
# wkday_2         -0.019163 -0.006805 -0.029508 -0.007472 -0.006751
# ...

# %%
import seaborn as sns
corr = full_data.corr()
plt.figure(figsize=(10,10))
plt.title('Twitter Data Correlations')
sns.heatmap(corr, xticklabels=corr.columns.values, yticklabels=corr.columns.values)
